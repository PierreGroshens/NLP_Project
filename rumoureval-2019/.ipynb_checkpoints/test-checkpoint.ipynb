# %%
import json
import os
import fnmatch
import pandas as pd
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
####### example to access text of json file


s1 = pd.Series([0,'test', 0])
df = pd.DataFrame([list(s1)], columns=['id', 'text','label'])
index = 0

for path, dirs, files in os.walk('twitter-english/'):
    if (path.endswith('source-tweet') or path.endswith('replies')):
        for filename in os.listdir(path):
            if filename.endswith('.json'):
                with open(os.path.join(path,filename)) as jsonFile:
                    jsonSourceTweet = json.load(jsonFile)

                    text_tweet = jsonSourceTweet['text']
                    id_tweet = int(re.sub("[^0-9]", "", filename))

                    newline = [id_tweet, text_tweet, index]
                    df.loc[index] = newline

                    index += 1

# %%
df.head()
# Out:
#                    id                                               text  \
# 0  529661510369284096  @mikeyerxa EXCUSE ME, WHERE'S MY INVITE (to th...
# 1  529661727940431872  @halihamilton @mikeyerxa gonna try to make it ...
# 2  529661317087768576  @mikeyerxa you should send Prince a set of ten...
# 3  529666750330449920  @NobleRobel Girl, don't be mean.   Age ain't n...
# 4  529660296080916480  Prince is playing a secret show in Toronto ton...
#
#    label
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
df_label = pd.read_json('train-key.json')

# %%
df_label.columns = ['label', 'b']
df_label.head()
# Out:
#                       label    b
# 501760642928635904  comment  NaN
# 500270212198174720  comment  NaN
# 524971210275565568  comment  NaN
# 552836882770690049  comment  NaN
# 500289931097296897  support  NaN

# %%
for i in range(len(df)):
    try:
        index = df.loc[i].id
        df.loc[i, 'label'] = df_label.loc[str(index)].label
    except KeyError:
        df.loc[i, 'label'] = 'not_found'
df.label.value_counts()
# Out:
# comment      2907
# not_found    1049
# support       910
# query         358
# deny          344
# Name: label, dtype: int64

# %%
#save not found labels because they are the eval data
index_to_save = df[df.label == "not_found"].index
mask_save = df.index.isin(index_to_save)
df_eval = df[mask_save]
df_label_eval = pd.read_json('dev-key.json')
df_label_eval.columns = ['label', 'b']


for i in range(len(df_eval)):
    index = df_eval.iloc[i].id
    df_eval.loc[i, 'label'] = df_label_eval.loc[str(int(index))].label
# Out:
# <ipython-input-15-e2105947a041>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eval.loc[i, 'label'] = df_label_eval.loc[str(int(index))].label
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '524978844155912192'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e2105947a041> in <module>
#       9 for i in range(len(df_eval)):
#      10     index = df_eval.iloc[i].id
# ---> 11     df_eval.loc[i, 'label'] = df_label_eval.loc[str(int(index))].label
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: '524978844155912192'

# %%
type(df.id)
# Out:
# pandas.core.series.Series

# %%
#df_eval.to_csv('eval_data.csv')

# %%
#get rid of not found tag

index_to_delete = df[df.label == "not_found"].index
mask = np.logical_not(df.index.isin(index_to_delete))

df_final = df[mask]
df_final.label.value_counts()
# Out:
# 2047    1
# 621     1
# 4707    1
# 2660    1
# 613     1
#        ..
# 3287    1
# 5336    1
# 1242    1
# 3291    1
# 0       1
# Name: label, Length: 5568, dtype: int64

# %%
def create_data(path_training, path_answer):
    s1 = pd.Series([0,'test', 0])
    df = pd.DataFrame([list(s1)], columns=['id', 'text','label'])
    index = 0

    for path, dirs, files in os.walk(path_training):
        if (path.endswith('source-tweet') or path.endswith('replies')):
            for filename in os.listdir(path):
                if filename.endswith('.json'):
                    with open(os.path.join(path,filename)) as jsonFile:
                        jsonSourceTweet = json.load(jsonFile)

                        text_tweet = jsonSourceTweet['text']
                        id_tweet = int(re.sub("[^0-9]", "", filename))

                        newline = [id_tweet, text_tweet, index]
                        df.loc[index] = newline

                        index += 1

    #rename column into label                    
    df_label = pd.read_json(path_answer)
    first_col = df_label.columns[0]
    df_label.rename(columns={first_col:'label'}, inplace=True)
    
    #add labels
    for i in range(len(df)):
        try:
            index = df.loc[i].id
            df.loc[i, 'label'] = df_label.loc[str(index)].label
        except KeyError:
            df.loc[i, 'label'] = 'not_found'

    #delete unecessary labels
    index_to_delete = df[df.label == "not_found"].index
    mask = np.logical_not(df.index.isin(index_to_delete))
    df_final = df[mask]


    return df_final

#tes_data_csv = create_data('twitter-en-test-data', 'final-eval-key.json')

# %%
tweets = df.text

# %%
df.loc[9].text
# Out:
# "@davidleyes @EntCity: I'm crying as well... Don't you worry!"

# %%
tweets.str.contains('http') & tweets.str.contains('#')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5563    False
# 5564    False
# 5565    False
# 5566    False
# 5567     True
# Name: text, Length: 5568, dtype: bool

# %%
example_tweet = tweets.loc[5567]
example_tweet
# Out:
# "Was Vladimir Putin netralized by an internal coup? Or maybe he's vacationing in Harper's closet:  http://t.co/tlr3cFLEyv #LookingForNarnia"

# %%
#remove links
re.sub(r'http\S+', '', example_tweet)
# Out:
# "Was Vladimir Putin netralized by an internal coup? Or maybe he's vacationing in Harper's closet:   #LookingForNarnia"

# %%
import string
def clean_data(text):
    #remove links
    text = re.sub(r'http\S+', '', text)

    #remove punct except @
    punc_to_remove = string.punctuation
    punc_to_remove.replace('@', '')
    text = "".join([char for char in text if char not in punc_to_remove])
          
    #lower case
    return text.lower()

# %%
token_tweet = word_tokenize(example_tweet)
token_tweet[1]
# Out:
# 'Vladimir'

# %%
stop_words = stopwords.words('english')
token_tweet = word_tokenize(example_tweet)
text = [word for word in token_tweet if word not in stop_words]
text
# Out:
# ['Was',
#  'Vladimir',
#  'Putin',
#  'netralized',
#  'internal',
#  'coup',
#  '?',
#  'Or',
#  'maybe',
#  "'s",
#  'vacationing',
#  'Harper',
#  "'s",
#  'closet',
#  ':',
#  'http',
#  ':',
#  '//t.co/tlr3cFLEyv',
#  '#',
#  'LookingForNarnia']

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
for i in range(len(df)):
    tweet = df.loc[i].text
    tweet_tokens = word_tokenize(tweet)
    #without stop words
    tweet_tokens_wst = [word for word in tweet_tokens if word not in stop_words]
    tweet_tokens_wst = TreebankWordDetokenizer().detokenize(tweet_tokens_wst)
    df.loc[i, 'text'] = tweet_tokens_wst

# %%
from nltk import WordNetLemmatizer
tweet = df.loc[460].text
wn = WordNetLemmatizer()
tokens = word_tokenize(tweet)
text = [wn.lemmatize(word) for word in tokens]
text
# Out:
# ['@',
#  'DaryusAzad',
#  '@',
#  'CBCAlerts',
#  '@',
#  'CBCNews',
#  '@',
#  'JustinTrudeau',
#  ',',
#  'radical',
#  'Muslim',
#  'extremist',
#  'making',
#  'u',
#  'victim',
#  '.']

# %%
df.label.value_counts()
# Out:
# comment      2907
# not_found    1049
# support       910
# query         358
# deny          344
# Name: label, dtype: int64

# %%
def fill_parent_id(structure):
    while bool(structure) == True:
        source_tweet = list(structure.keys())[0]
        structure = structure.pop(source_tweet)
        for first_child in structure:
            

            df.loc[df.id == int(first_child), "parent_id"] = int(source_tweet)


            try:
                last_child = list(structure.get(first_child))[0]
                df.loc[df.id == int(last_child), "parent_id"] = int(first_child)
            except IndexError:
                continue
            #print("last\n", last_child)
            #print("first\n", first_child)

# %%
####### example to access text of json file



for path, dirs, files in os.walk('twitter-english/'):

    if path[-1].isdigit():
        if path.endswith('580348081100734464'):

            for _, _, files in os.walk(path):
                for file in files:
                    if file.endswith('structure.json'):


                        with open(os.path.join(path, file)) as jsonFile:

                            structure = json.load(jsonFile)
                            #fill_parent_id(structure)



def fill_parent_id_version_2(structure):

        source_tweet = list(structure.keys())[0]
        structure = structure.pop(source_tweet)
        for first_child in structure:
            
            #df.loc[df.id == int(first_child), "parent_id"] = int(source_tweet)
            global line
            line = structure.get(first_child)

            if (len(line) > 0):
                print(line)
                break
                
             #   break
            #while childs have sons keep going
#            while structure.get(first_child):
                
 #               print(sub_structure.get(first_child))

fill_parent_id_version_2(structure)
# Out:
# {'580350715408859136': [], '580350976026112000': {'580351508971200512': {'580358103255879680': {'580358531850866688': []}, '580418932152102912': []}, '580353327470247936': [], '580354381578522625': [], '580355004294250496': [], '580421457974566912': {'580422091155095552': [], '580422272575533056': []}}, '580351698545319937': [], '580355513050763264': []}

# %%
df
# Out:
#                       id                                               text  \
# 0     529661510369284096  @mikeyerxa EXCUSE ME, WHERE'S MY INVITE (to th...
# 1     529661727940431872  @halihamilton @mikeyerxa gonna try to make it ...
# 2     529661317087768576  @mikeyerxa you should send Prince a set of ten...
# 3     529666750330449920  @NobleRobel Girl, don't be mean.   Age ain't n...
# 4     529660296080916480  Prince is playing a secret show in Toronto ton...
# ...                  ...                                                ...
# 5563  577283431089901568  @PatOndabak It is disconcerting that the man w...
# 5564  577282462788677634  @PatOndabak or maybe he just needs a break fro...
# 5565  577284294051123201  @patondabak Maybe, just maybe… he's huddling w...
# 5566  577260238316830721  @PatOndabak I'm going with neutralized and the...
# 5567  577258317942149120  Was Vladimir Putin netralized by an internal c...
#
#       label
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 5563   5563
# 5564   5564
# 5565   5565
# 5566   5566
# 5567   5567
#
# [5568 rows x 3 columns]

# %%
import json
for path, dirs, files in os.walk('twitter-english/'):


    if (path.endswith("replies")):

        for _, _, files in os.walk(path):
            for file in files:

                with open(os.path.join(path,file)) as jsonFile:
                    data = json.load(jsonFile)
                    parent_id = data["in_reply_to_status_id"]

                    df.loc[df.id == file, "parent_id"] = parent_id
# Out:
# twitter-english/prince-toronto/529660296080916480/replies
# twitter-english/prince-toronto/529653029747064832/replies
# twitter-english/prince-toronto/529687410611728384/replies
# twitter-english/prince-toronto/529713467184676864/replies
# twitter-english/prince-toronto/529689679411810304/replies
# twitter-english/prince-toronto/529716453792956416/replies
# twitter-english/prince-toronto/529695367680761856/replies
# twitter-english/prince-toronto/529695483661664257/replies
# twitter-english/prince-toronto/529739968470867968/replies
# twitter-english/prince-toronto/529540733020405760/replies
# twitter-english/prince-toronto/529654186791944192/replies
# twitter-english/prince-toronto/529720273285566464/replies
# twitter-english/ottawashooting/524990163446140928/replies
# twitter-english/ottawashooting/524947416869388288/replies
# twitter-english/ottawashooting/524942470472548352/replies
# twitter-english/ottawashooting/525032872647065600/replies
# twitter-english/ottawashooting/524925050739490816/replies
# twitter-english/ottawashooting/525028734991343617/replies
# twitter-english/ottawashooting/524959809402331137/replies
# twitter-english/ottawashooting/524948206023880704/replies
# twitter-english/ottawashooting/524993533212897281/replies
# twitter-english/ottawashooting/525056576038518785/replies
# twitter-english/ottawashooting/524923676484177920/replies
# twitter-english/ottawashooting/524949443607412737/replies
# twitter-english/ottawashooting/525049639016615937/replies
# twitter-english/ottawashooting/524926235030589440/replies
# twitter-english/ottawashooting/524927281048080385/replies
# twitter-english/ottawashooting/525003468659228672/replies
# twitter-english/ottawashooting/524932935137628160/replies
# twitter-english/ottawashooting/525068915068923904/replies
# twitter-english/ottawashooting/524931324763992064/replies
# twitter-english/ottawashooting/524975705206304769/replies
# twitter-english/ottawashooting/524947674164760577/replies
# twitter-english/ottawashooting/524926472432410625/replies
# twitter-english/ottawashooting/525019752507658240/replies
# twitter-english/ottawashooting/524932056560963584/replies
# twitter-english/ottawashooting/525023025792835585/replies
# twitter-english/ottawashooting/524964948683005952/replies
# twitter-english/ottawashooting/524944399890124801/replies
# twitter-english/ottawashooting/524970851675176960/replies
# twitter-english/ottawashooting/524983581983375360/replies
# twitter-english/ottawashooting/524947867975561216/replies
# twitter-english/ottawashooting/524969201102901248/replies
# twitter-english/ottawashooting/524965775036387329/replies
# twitter-english/ottawashooting/524937542131793920/replies
# twitter-english/ottawashooting/524922729485848576/replies
# twitter-english/ottawashooting/524981436252950528/replies
# twitter-english/ottawashooting/524972443308683264/replies
# twitter-english/ottawashooting/524925987239120897/replies
# twitter-english/ottawashooting/525025463648137216/replies
# twitter-english/ottawashooting/524940659778920448/replies
# twitter-english/ottawashooting/524936872666353664/replies
# twitter-english/ottawashooting/524961721744900097/replies
# twitter-english/ottawashooting/524962142563610625/replies
# twitter-english/ottawashooting/524956129017995264/replies
# twitter-english/ottawashooting/524935485370929152/replies
# twitter-english/ottawashooting/525025279803424768/replies
# twitter-english/ottawashooting/524980744658382848/replies
# twitter-english/ottawashooting/524925730053181440/replies
# twitter-english/ottawashooting/524941720249978880/replies
# twitter-english/ottawashooting/525060425184858112/replies
# twitter-english/ottawashooting/525058976376193024/replies
# twitter-english/ottawashooting/524966904885428226/replies
# twitter-english/ottawashooting/524923462398513152/replies
# twitter-english/ottawashooting/524943490887991296/replies
# twitter-english/ottawashooting/524991576163250176/replies
# twitter-english/ottawashooting/524925215235911680/replies
# twitter-english/ottawashooting/524923293711998976/replies
# twitter-english/ottawashooting/524924619812511746/replies
# twitter-english/ottawashooting/524952883343925249/replies
# twitter-english/ottawashooting/524936793633083394/replies
# twitter-english/ottawashooting/524948866773184512/replies
# twitter-english/ottawashooting/524929497205055488/replies
# twitter-english/ottawashooting/524941132237910016/replies
# twitter-english/ottawashooting/524995771587108864/replies
# twitter-english/illary/758159624122097664/replies
# twitter-english/illary/767725956706414592/replies
# twitter-english/illary/763098277986209792/replies
# twitter-english/illary/775057555865206784/replies
# twitter-english/illary/774991078265094144/replies
# twitter-english/illary/768859780240773121/replies
# twitter-english/illary/764927075522260992/replies
# twitter-english/illary/769988636754505729/replies
# twitter-english/germanwings-crash/581153923987206146/replies
# twitter-english/germanwings-crash/580326222107951104/replies
# twitter-english/germanwings-crash/580371845997682688/replies
# twitter-english/germanwings-crash/581063377226637312/replies
# twitter-english/germanwings-crash/580339825649291264/replies
# twitter-english/germanwings-crash/580339547269144576/replies
# twitter-english/germanwings-crash/580352273001410560/replies
# twitter-english/germanwings-crash/580320684305416192/replies
# twitter-english/germanwings-crash/580360165540642816/replies
# twitter-english/germanwings-crash/581359544682614784/replies
# twitter-english/germanwings-crash/580340476949086208/replies
# twitter-english/germanwings-crash/580333763512705025/replies
# twitter-english/germanwings-crash/580319184652890113/replies
# twitter-english/germanwings-crash/580325090367315968/replies
# twitter-english/germanwings-crash/581290271997968384/replies
# twitter-english/germanwings-crash/580319078155468800/replies
# twitter-english/germanwings-crash/580331561398108160/replies
# twitter-english/germanwings-crash/580323060533764097/replies
# twitter-english/germanwings-crash/580321156508577792/replies
# twitter-english/germanwings-crash/581386094337474560/replies
# twitter-english/germanwings-crash/581293286268129280/replies
# twitter-english/germanwings-crash/580322453928431617/replies
# twitter-english/germanwings-crash/580348081100734464/replies
# twitter-english/germanwings-crash/580332109782466561/replies
# twitter-english/germanwings-crash/581473088249958400/replies
# twitter-english/germanwings-crash/580333909008871424/replies
# twitter-english/germanwings-crash/580324027715063808/replies
# twitter-english/germanwings-crash/581047170637381632/replies
# twitter-english/germanwings-crash/580882341880446977/replies
# twitter-english/ebola-essien/521346721226711040/replies
# twitter-english/ebola-essien/521360486387175424/replies
# twitter-english/charliehebdo/553486439129038848/replies
# twitter-english/charliehebdo/552978099357237248/replies
# twitter-english/charliehebdo/552785375161499649/replies
# twitter-english/charliehebdo/553549686129561600/replies
# twitter-english/charliehebdo/552806757672964097/replies
# twitter-english/charliehebdo/553544252563935234/replies
# twitter-english/charliehebdo/552996335319007233/replies
# twitter-english/charliehebdo/553480082996879360/replies
# twitter-english/charliehebdo/552788945017516032/replies
# twitter-english/charliehebdo/553586897168392192/replies
# twitter-english/charliehebdo/553535829017370625/replies
# twitter-english/charliehebdo/553561170637238272/replies
# twitter-english/charliehebdo/553512735192141826/replies
# twitter-english/charliehebdo/553476880339599360/replies
# twitter-english/charliehebdo/553544694765215745/replies
# twitter-english/charliehebdo/552982613288157184/replies
# twitter-english/charliehebdo/553221600955621376/replies
# twitter-english/charliehebdo/553506608203169792/replies
# twitter-english/charliehebdo/553152395371630592/replies
# twitter-english/charliehebdo/553164985460068352/replies
# twitter-english/charliehebdo/553503184174710784/replies
# twitter-english/charliehebdo/553590835850514433/replies
# twitter-english/charliehebdo/553538058440941568/replies
# twitter-english/charliehebdo/552821069036670976/replies
# twitter-english/charliehebdo/553107921081749504/replies
# twitter-english/charliehebdo/553576010898497536/replies
# twitter-english/charliehebdo/552833028201144320/replies
# twitter-english/charliehebdo/552792802309181440/replies
# twitter-english/charliehebdo/553467311261503488/replies
# twitter-english/charliehebdo/553587672137334785/replies
# twitter-english/charliehebdo/552832817089236992/replies
# twitter-english/charliehebdo/553461741917863936/replies
# twitter-english/charliehebdo/552816020403269632/replies
# twitter-english/charliehebdo/553531413459660800/replies
# twitter-english/charliehebdo/552811386259386370/replies
# twitter-english/charliehebdo/552978184413921281/replies
# twitter-english/charliehebdo/553489393202499584/replies
# twitter-english/charliehebdo/553575232867672064/replies
# twitter-english/charliehebdo/552814494381256704/replies
# twitter-english/charliehebdo/553566026030272512/replies
# twitter-english/charliehebdo/552802654641225728/replies
# twitter-english/charliehebdo/552791196247269378/replies
# twitter-english/charliehebdo/553534838880608256/replies
# twitter-english/charliehebdo/553505242554175489/replies
# twitter-english/charliehebdo/553553288625672192/replies
# twitter-english/charliehebdo/553587013409325058/replies
# twitter-english/charliehebdo/553589051044151296/replies
# twitter-english/charliehebdo/552810448324943872/replies
# twitter-english/charliehebdo/553590459688570880/replies
# twitter-english/charliehebdo/553508098825261056/replies
# twitter-english/charliehebdo/553579224402235393/replies
# twitter-english/charliehebdo/552806309540528128/replies
# twitter-english/charliehebdo/553548567420628992/replies
# twitter-english/charliehebdo/553543369604210689/replies
# twitter-english/charliehebdo/552791578893619200/replies
# twitter-english/charliehebdo/552793679082311680/replies
# twitter-english/charliehebdo/553160652567498752/replies
# twitter-english/charliehebdo/553550301886955520/replies
# twitter-english/charliehebdo/553470492565602305/replies
# twitter-english/charliehebdo/552984502063337472/replies
# twitter-english/charliehebdo/553588178687655936/replies
# twitter-english/charliehebdo/552792544132997121/replies
# twitter-english/charliehebdo/553212962044149761/replies
# twitter-english/charliehebdo/552805488631758849/replies
# twitter-english/charliehebdo/552783667052167168/replies
# twitter-english/charliehebdo/553197863971610624/replies
# twitter-english/charliehebdo/553586860334010368/replies
# twitter-english/charliehebdo/553558982476828674/replies
# twitter-english/charliehebdo/553478289474740224/replies
# twitter-english/charliehebdo/553518472798683136/replies
# twitter-english/charliehebdo/553476490315431937/replies
# twitter-english/charliehebdo/553587303172833280/replies
# twitter-english/charliehebdo/552834961762709505/replies
# twitter-english/charliehebdo/553501357156876290/replies
# twitter-english/charliehebdo/553474188259102720/replies
# twitter-english/charliehebdo/552848620375261184/replies
# twitter-english/charliehebdo/553184482241814530/replies
# twitter-english/charliehebdo/552792913910833152/replies
# twitter-english/sydneysiege/544306719686656000/replies
# twitter-english/sydneysiege/544333764814323713/replies
# twitter-english/sydneysiege/544512910538838016/replies
# twitter-english/sydneysiege/544292129972170752/replies
# twitter-english/sydneysiege/544514564407427072/replies
# twitter-english/sydneysiege/544289941996326912/replies
# twitter-english/sydneysiege/544305540286148609/replies
# twitter-english/sydneysiege/544278985249550337/replies
# twitter-english/sydneysiege/544290258951892992/replies
# twitter-english/sydneysiege/544314234541469696/replies
# twitter-english/sydneysiege/544287209730236416/replies
# twitter-english/sydneysiege/544268732046913536/replies
# twitter-english/sydneysiege/544328894812549121/replies
# twitter-english/sydneysiege/544391533240516608/replies
# twitter-english/sydneysiege/544278335455776769/replies
# twitter-english/sydneysiege/544504183341064192/replies
# twitter-english/sydneysiege/544288681021145090/replies
# twitter-english/sydneysiege/544358564484378624/replies
# twitter-english/sydneysiege/544399927045283840/replies
# twitter-english/sydneysiege/544491151118860289/replies
# twitter-english/sydneysiege/544271069146656768/replies
# twitter-english/sydneysiege/544374511194632192/replies
# twitter-english/sydneysiege/544517264054423552/replies
# twitter-english/sydneysiege/544272537341812736/replies
# twitter-english/sydneysiege/544324444773433348/replies
# twitter-english/sydneysiege/544309275141885952/replies
# twitter-english/sydneysiege/544301453717041152/replies
# twitter-english/sydneysiege/544358533819420672/replies
# twitter-english/sydneysiege/544350712365207552/replies
# twitter-english/sydneysiege/544513524438155264/replies
# twitter-english/sydneysiege/544462330105712640/replies
# twitter-english/sydneysiege/544319832486064128/replies
# twitter-english/sydneysiege/544382892378714113/replies
# twitter-english/sydneysiege/544380742076088320/replies
# twitter-english/sydneysiege/544292670336925696/replies
# twitter-english/sydneysiege/544515538383564801/replies
# twitter-english/sydneysiege/544319274072817664/replies
# twitter-english/sydneysiege/544512664769396736/replies
# twitter-english/sydneysiege/544512108885725184/replies
# twitter-english/sydneysiege/544510450101415936/replies
# twitter-english/sydneysiege/544277860555710464/replies
# twitter-english/sydneysiege/544269749405097984/replies
# twitter-english/sydneysiege/544381485591982083/replies
# twitter-english/sydneysiege/544282005941530624/replies
# twitter-english/sydneysiege/544511199702822913/replies
# twitter-english/sydneysiege/544305745416581120/replies
# twitter-english/sydneysiege/544271362022338560/replies
# twitter-english/sydneysiege/544367462012432384/replies
# twitter-english/sydneysiege/544271284796784640/replies
# twitter-english/sydneysiege/544297696308518912/replies
# twitter-english/sydneysiege/544352727971954690/replies
# twitter-english/sydneysiege/544289311504355328/replies
# twitter-english/sydneysiege/544283772569788416/replies
# twitter-english/sydneysiege/544274934835707905/replies
# twitter-english/sydneysiege/544512676643500033/replies
# twitter-english/sydneysiege/544520273718812672/replies
# twitter-english/sydneysiege/544350567183556608/replies
# twitter-english/sydneysiege/544293753130082305/replies
# twitter-english/sydneysiege/544294893146091520/replies
# twitter-english/sydneysiege/544476808566276097/replies
# twitter-english/sydneysiege/544520042810200064/replies
# twitter-english/sydneysiege/544391176137089024/replies
# twitter-english/sydneysiege/544289409294553088/replies
# twitter-english/sydneysiege/544274544174071809/replies
# twitter-english/sydneysiege/544291804057960448/replies
# twitter-english/sydneysiege/544282227035869184/replies
# twitter-english/sydneysiege/544315472075042818/replies
# twitter-english/sydneysiege/544518335019229184/replies
# twitter-english/sydneysiege/544306402731507712/replies
# twitter-english/sydneysiege/544291965513134080/replies
# twitter-english/sydneysiege/544310853613281281/replies
# twitter-english/sydneysiege/544329935943237632/replies
# twitter-english/sydneysiege/544277117039837184/replies
# twitter-english/sydneysiege/544514570367168512/replies
# twitter-english/ferguson/500381163866062848/replies
# twitter-english/ferguson/500308076004929537/replies
# twitter-english/ferguson/500391222075076610/replies
# twitter-english/ferguson/500307001629745152/replies
# twitter-english/ferguson/498430783699554305/replies
# twitter-english/ferguson/500280838710247424/replies
# twitter-english/ferguson/500298588992593920/replies
# twitter-english/ferguson/500394061887709184/replies
# twitter-english/ferguson/500363740311982081/replies
# twitter-english/ferguson/500377906305327104/replies
# twitter-english/ferguson/500341884678836224/replies
# twitter-english/ferguson/500298752469770240/replies
# twitter-english/ferguson/500258409988763649/replies
# twitter-english/ferguson/500286058664579072/replies
# twitter-english/ferguson/500280422295937024/replies
# twitter-english/ferguson/500281131057811456/replies
# twitter-english/ferguson/500270780832174080/replies
# twitter-english/ferguson/499366666300846081/replies
# twitter-english/ferguson/499612545909415938/replies
# twitter-english/ferguson/500363126294863876/replies
# twitter-english/ferguson/500303431928922113/replies
# twitter-english/ferguson/500413818368184321/replies
# twitter-english/ferguson/500371149713178625/replies
# twitter-english/ferguson/500389488217309184/replies
# twitter-english/ferguson/500378223977721856/replies
# twitter-english/ferguson/500281094239817728/replies
# twitter-english/ferguson/500294803402137600/replies
# twitter-english/ferguson/500279189405433858/replies
# twitter-english/ferguson/498280126254428160/replies
# twitter-english/ferguson/500327106824245249/replies
# twitter-english/ferguson/500319675797209088/replies
# twitter-english/ferguson/500332933098385408/replies
# twitter-english/ferguson/499456140044824576/replies
# twitter-english/ferguson/500295393301647360/replies
# twitter-english/ferguson/500280249629036544/replies
# twitter-english/ferguson/500319801344929795/replies
# twitter-english/ferguson/498293668655423488/replies
# twitter-english/ferguson/500377145349521411/replies
# twitter-english/ferguson/500327120770301952/replies
# twitter-english/ferguson/500290456845299714/replies
# twitter-english/ferguson/500347114975944705/replies
# twitter-english/ferguson/499368931367608320/replies
# twitter-english/ferguson/500354773133299713/replies
# twitter-english/ferguson/500284699546517505/replies
# twitter-english/ferguson/500378522788315137/replies
# twitter-english/ferguson/500279160795721728/replies
# twitter-english/ferguson/499530130487017472/replies
# twitter-english/ferguson/498486826269548545/replies
# twitter-english/ferguson/500288349924782080/replies
# twitter-english/ferguson/500278045597368320/replies
# twitter-english/putinmissing/576323086888361984/replies
# twitter-english/putinmissing/576796432730071040/replies
# twitter-english/putinmissing/576829262927413248/replies
# twitter-english/putinmissing/576276947648405505/replies
# twitter-english/putinmissing/576319832800555008/replies
# twitter-english/putinmissing/576755174531862529/replies
# twitter-english/putinmissing/576513463738109954/replies
# twitter-english/putinmissing/576812998418939904/replies
# twitter-english/putinmissing/577258317942149120/replies

# %%
####### example to access text of json file


s1 = pd.Series([0,'test', 0])
df = pd.DataFrame([list(s1)], columns=['id', 'text','label'])
index = 0

for path, dirs, files in os.walk('twitter-english/'):
    if (path.endswith('source-tweet') or path.endswith('replies')):
        for filename in os.listdir(path):
            if filename.endswith('.json'):
                with open(os.path.join(path,filename)) as jsonFile:
                    jsonSourceTweet = json.load(jsonFile)

                    text_tweet = jsonSourceTweet['text']
                    id_tweet = int(re.sub("[^0-9]", "", filename))

                    newline = [id_tweet, text_tweet, index]
                    df.loc[index] = newline

                    index += 1
